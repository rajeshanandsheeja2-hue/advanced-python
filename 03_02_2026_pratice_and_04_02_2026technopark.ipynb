# %% [markdown]
# <a href="https://colab.research.google.com/github/rajeshanandsheeja2-hue/advanced-python/blob/main/03_02_2026_pratice_and_04_02_2026technopark.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=3
b=4
c=5
if a>b and a>c:
  print("a greater ")
elif b>a and b>c:
  print("b greater")
else:
  print("c greater")
# Out:
# c greater

# %%
for i in range(100,801):
  if(i%3==0 and i%7==0):
    print(i)
# Out:
# 105
# 126
# 147
# 168
# 189
# 210
# 231
# 252
# 273
# 294
# 315
# 336
# 357
# 378
# 399
# 420
# 441
# 462
# 483
# 504
# 525
# 546
# 567
# 588
# 609
# 630
# 651
# 672
# 693
# 714
# 735
# 756
# 777
# 798

# %%
count=0
for i in range(1,1001):
  if(i%8==0):
    count=count+1
print(count)
# Out:
# 125

# %%
for i in range(1,6):
  print('*'*i)
# Out:
# *
# **
# ***
# ****
# *****

# %%
for i in range(1,16):
 if(i%2!=0):
  print(f'the number {i} is 0dd')
 else:
    print(f'the number {i} is even')
# Out:
# the number 1 is 0dd
# the number 2 is even
# the number 3 is 0dd
# the number 4 is even
# the number 5 is 0dd
# the number 6 is even
# the number 7 is 0dd
# the number 8 is even
# the number 9 is 0dd
# the number 10 is even
# the number 11 is 0dd
# the number 12 is even
# the number 13 is 0dd
# the number 14 is even
# the number 15 is 0dd

# %%
num=int(input("enter the number"))
fact=1
for i in range(1,num+1):
  fact=fact*i
  print("factorial",fact)
# Out:
# enter the number6
# factorial 1
# factorial 2
# factorial 6
# factorial 24
# factorial 120
# factorial 720

# %%
n=4
for i in range(1,6):
  print(i)
def fact(n):
  print()
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
def multipy(n):
  print(n*2)
multipy(10)
# Out:
# 20

# %%
def send_gift(recipient,gift):
  print(f"sending {gift} to {recipient}!")
send_gift("asif","girlfirend")
print()
# Out:
# sending girlfirend to asif!

# %%
def send_gift(recipient,gift):
  print(f"sending {gift} to {recipient}!")
send_gift(gift="a camera",recipient="Bob")
# Out:
# sending a camera to Bob!

# %% [markdown]
# abs(),callable(),getattr(),globals(),0rd()

# %%
def book_trip(destination,transport):
  print(f"booking a {transport} to {destination}")
book_trip("new york","filght")
# Out:
# booking a filght to new york

# %%
def book_ticket(destination,transport):
  print(f"booking a {transport} to {destination}")
book_ticket(transport="train",destination="london")
# Out:
# booking a train to london

# %%
def book_trip(destination="uk",transport="flight"):
  print(f"booking a {transport} to {destination}")
book_trip()
# Out:
# booking a flight to uk

# %%
def book_trip(destination,transport="flight"):
  print(f"booking a {transport} to {destination}")
book_trip("uk","train")
# Out:
# booking a train to uk

# %%
def book_trip(destination,*things):
  print(f" in  {destination} we can enjoy {things}")
book_trip("norway","seasons","cilmate","culture")
# Out:
#  in  norway we can enjoy ('seasons', 'cilmate', 'culture')

# %%
def add_numbers(a,b):
  print(a+b)
result = add_numbers(5,5)
# Out:
# 10

# %%
def add_numbers(a,b):
  return  a+b
result= add_numbers

# %%
def add_ten(number):
  print(number + 10)
my_result=add_ten(5)
final_answer=my_result*2
print(f"the final answer is:{final_answer}")
# Out:
# 15
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2363703808.py in <cell line: 0>()
#       2   print(number + 10)
#       3 my_result=add_ten(5)
# ----> 4 final_answer=my_result*2
#       5 print(f"the final answer is:{final_answer}")
#
# TypeError: unsupported operand type(s) for *: 'NoneType' and 'int'

# %%
def add_ten(number):
  return number + 10
my_result=add_ten(5)
final_answer=my_result*2
print(f"the final answer is {final_answer}")
# Out:
# the final answer is 30

# %%
def square(x):
  sq=x*x
  return sq
square(5)
# Out:
# 25

# %%
square = lambda  x:x*x
square(5)
# Out:
# 25

# %%
addition = lambda x,y:x+y
addition(10,20)
# Out:
# 30

# %%
is_pass=lambda marks:"pass" if marks>40 else "fail"
is_pass(55)
# Out:
# 'pass'

# %%
def square(x):
  sq=x*x
  return sq
numbers=[1,2,3,4,5]
squares=map(square,numbers)
list(squares)
# Out:
# [1, 4, 9, 16, 25]

# %%
numbers=[1,2,3,4,5]
squares=map(lambda x:x*x,numbers)
list(squares)
# Out:
# [1, 4, 9, 16, 25]

# %%
numbers=[1,2,3,4,5]
squares=list(map(lambda x:x*x,numbers))
squares
# Out:
# [1, 4, 9, 16, 25]

# %%
list_a=[1,2,3]
list_b=[4,5,6]
sum_list=list(map(lambda x,y:x+y,list_a,list_b))
sum_list
# Out:
# [5, 7, 9]

# %%
list_1=[1,2,3,-1,-4,-5,4,5]
sum_list=list(filter(lambda x:x>0,list_1))
sum_list
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# git init
# git clone
# git pull
# git status
# git add
# git commit
# git push
# merge
